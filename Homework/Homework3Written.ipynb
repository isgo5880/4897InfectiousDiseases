# %% [markdown]
# # Homework 3

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ### 1a.
#
# Based on the information given in the problem, since there are four groups, we will have four $I$ equations that look like the following:
#
# $$\dot{I_1} = pS_1c_{11}\frac{I_1}{N_1} + pS_1c_{12}\frac{I_2}{N_2} + pS_1c_{13}\frac{I_3}{N_3} + pS_1c_{14}\frac{I_4}{N_4} - \gamma I_1$$
#
# $$\dot{I_2} = pS_2c_{21}\frac{I_1}{N_1} + pS_2c_{22}\frac{I_2}{N_2} + pS_2c_{23}\frac{I_3}{N_3} + pS_2c_{24}\frac{I_4}{N_4} - \gamma I_2$$
#
# $$\dot{I_3} = pS_3c_{31}\frac{I_1}{N_1} + pS_3c_{32}\frac{I_2}{N_2} + pS_3c_{33}\frac{I_3}{N_3} + pS_3c_{34}\frac{I_4}{N_4} - \gamma I_3$$
#
# $$\dot{I_4} = pS_4c_{41}\frac{I_1}{N_1} + pS_4c_{42}\frac{I_2}{N_2} + pS_4c_{43}\frac{I_3}{N_3} + pS_4c_{44}\frac{I_4}{N_4} - \gamma I_4$$
#
# We have different susceptibilities for each group, a consistent gamma parameter, and the contact structure is fully mixed, so we can simplify the above equations to the following:
#
# $$\dot{I_1} = S_1\bar{c}\frac{I_1}{N_1} + S_1\bar{c}\frac{I_2}{N_2} + S_1\bar{c}\frac{I_3}{N_3} + S_1\bar{c}\frac{I_4}{N_4} - 3I_1$$
#
# $$\dot{I_2} = 2S_2\bar{c}\frac{I_1}{N_1} + 2S_2\bar{c}\frac{I_2}{N_2} + 2S_2\bar{c}\frac{I_3}{N_3} + 2S_2\bar{c}\frac{I_4}{N_4} - 3I_2$$
#
# $$\dot{I_3} = 3S_3\bar{c}\frac{I_1}{N_1} + 3S_3\bar{c}\frac{I_2}{N_2} + 3S_3\bar{c}\frac{I_3}{N_3} + 3S_3\bar{c}\frac{I_4}{N_4} - 3I_3$$
#
# $$\dot{I_4} = 4S_4\bar{c}\frac{I_1}{N_1} + 4S_4\bar{c}\frac{I_2}{N_2} + 4S_4\bar{c}\frac{I_3}{N_3} + 4S_4\bar{c}\frac{I_4}{N_4} - 3I_4$$
#
# Taking the partial derivatives, we obtain the Jacobian:
#
# $$
# \begin{bmatrix}
# \frac{S_1}{N_1}\bar{c} - 3 & \frac{S_1}{N_2}\bar{c} & \frac{S_1}{N_3}\bar{c} & \frac{S_1}{N_4}\bar{c} \\
# 2\frac{S_2}{N_1}\bar{c} & 2\frac{S_2}{N_2}\bar{c} - 3 & 2\frac{S_2}{N_3}\bar{c} & 2\frac{S_2}{N_4}\bar{c} \\
# 3\frac{S_3}{N_1}\bar{c} & 3\frac{S_3}{N_2}\bar{c} & 3\frac{S_3}{N_3}\bar{c} - 3 & 3\frac{S_3}{N_4}\bar{c} \\
# 4\frac{S_4}{N_1}\bar{c} & 4\frac{S_4}{N_2}\bar{c} & 4\frac{S_4}{N_3}\bar{c} & 4\frac{S_4}{N_4}\bar{c} - 3
# \end{bmatrix}
# $$
#
# We can decompose this into $J = T + \Sigma$:
#
# $$
# \begin{bmatrix}
# -3 & 0 & 0 & 0 \\
# 0 & -2 & 0 & 0 \\
# 0 & 0 & -3 & 0 \\
# 0 & 0 & 0 & -3
# \end{bmatrix} + \begin{bmatrix}
# \frac{S_1}{N_1}\bar{c} & \frac{S_1}{N_2}\bar{c} & \frac{S_1}{N_3}\bar{c} & \frac{S_1}{N_4}\bar{c} \\
# 2\frac{S_2}{N_1}\bar{c} & 2\frac{S_2}{N_2}\bar{c} & 2\frac{S_2}{N_3}\bar{c} & 2\frac{S_2}{N_4}\bar{c} \\
# 3\frac{S_3}{N_1}\bar{c} & 3\frac{S_3}{N_2}\bar{c} & 3\frac{S_3}{N_3}\bar{c} & 3\frac{S_3}{N_4}\bar{c} \\
# 4\frac{S_4}{N_1}\bar{c} & 4\frac{S_4}{N_2}\bar{c} & 4\frac{S_4}{N_3}\bar{c} & 4\frac{S_4}{N_4}\bar{c}
# \end{bmatrix}
# $$
#
# The next generation matrix is given by $G = -T\Sigma^{-1}$:
#
# $$
# \begin{bmatrix}
# \frac{S_1}{N_1}\frac{\bar{c}}{3} & \frac{S_1}{N_2}\frac{\bar{c}}{3} & \frac{S_1}{N_3}\frac{\bar{c}}{3} & \frac{S_1}{N_4}\frac{\bar{c}}{3} \\
# \frac{S_2}{N_1}\frac{2\bar{c}}{3} & \frac{S_2}{N_2}\frac{2\bar{c}}{3} & \frac{S_2}{N_3}\frac{2\bar{c}}{3} & \frac{S_2}{N_4}\frac{2\bar{c}}{3} \\
# \frac{S_3}{N_1}\frac{3\bar{c}}{3} & \frac{S_3}{N_2}\frac{3\bar{c}}{3} & \frac{S_3}{N_3}\frac{3\bar{c}}{3} & \frac{S_3}{N_4}\frac{3\bar{c}}{3} \\
# \frac{S_4}{N_1}\frac{4\bar{c}}{3} & \frac{S_4}{N_2}\frac{4\bar{c}}{3} & \frac{S_4}{N_3}\frac{4\bar{c}}{3} & \frac{S_4}{N_4}\frac{4\bar{c}}{3}
# \end{bmatrix} = \begin{bmatrix}
# s_1\frac{\bar{c}}{3} & s_1\frac{\bar{c}}{3} & s_1\frac{\bar{c}}{3} & s_1\frac{\bar{c}}{3} \\
# s_2\frac{2\bar{c}}{3} & s_2\frac{2\bar{c}}{3} & s_2\frac{2\bar{c}}{3} & s_2\frac{2\bar{c}}{3} \\
# s_3\frac{3\bar{c}}{3} & s_3\frac{3\bar{c}}{3} & s_3\frac{3\bar{c}}{3} & s_3\frac{3\bar{c}}{3} \\
# s_4\frac{4\bar{c}}{3} & s_4\frac{4\bar{c}}{3} & s_4\frac{4\bar{c}}{3} & s_4\frac{4\bar{c}}{3}
# \end{bmatrix}
# $$

# %% [markdown]
# ### 1b.

# %% [markdown]
# Note that all groups are of the same size, and to estimate $R_0$ we assume $s_i = 1$, or that our population is entirely susceptible.
#
# $$
# G_0 = \begin{bmatrix}
# \frac{\bar{c}}{3} & \frac{\bar{c}}{3} & \frac{\bar{c}}{3} & \frac{\bar{c}}{3} \\
# \frac{2\bar{c}}{3} & \frac{2\bar{c}}{3} & \frac{2\bar{c}}{3} & \frac{2\bar{c}}{3} \\
# \bar{c} & \bar{c} & \bar{c} & \bar{c} \\
# \frac{4\bar{c}}{3} & \frac{4\bar{c}}{3} & \frac{4\bar{c}}{3} & \frac{4\bar{c}}{3}
# \end{bmatrix}
# $$

# %% [markdown]
# $R_0$ is given by the largest eigenvalue of the NGM evaluated at the disease free equilibrium, $G_0$.
#
# The trace of the matrix is $\frac{10\bar{c}}{3}$, which is the sum of the eigenvalues. I calculated the eigenvalues by hand, and found that there is an eigenvalue of 0 with multiplicity 3, and an eigenvalue equal to $\frac{10\bar{c}}{3}$, which aligns with what the trace is.
#
# This means that $R_0 = 1.5 = \frac{10\bar{c}}{3}$, and so $c = 0.45$.

# %% [markdown]
# ### 1c.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1d.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1e.

# %% [markdown]
# I can see that the groups that are more susceptible experience a higher proportion of infected people at the peak of infection, as we can see that group 4, which had the highest susceptibility at 4, also has the highest proportion of individuals infected. This also means that the number of susceptibles for group 4 should be the lowest, which we can see from the plot above. One thing to note is that all groups never deplete their susceptibles, indicating that the infection dies out in the population. This can also be confirmed by looking at the proportion of individuals infected for each group, which is under 10% for all groups. The average relative susceptibility is higher than the actual susceptibilities (which all start from one because we assumed everyone was susceptible at the start), because it is a weighted average of the susceptibilities, and since all groups have a relatively high susceptibility, especially at the start, the relative susceptibility will also be high, and above our actual population proportions.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ### 2a.

# %% [markdown]
# 0.1:  0.831
#
# 0.5:  0.52
#
# 1.0:  0.348
#
# 5.0:  0.119
#
# 10.0:  0.068

# %% [markdown]
# ### 1b.

# %% [markdown]
# The larger the k, the less likely it is for the epidemic to die out, whereas the smaller the k, the more superspreaders there are, and the more likely it is for the epidemic to die out. Since p is 1-q, and q is 1-p, the larger the k, the more likely it is for the epidemic to go on forever, and the smaller the k, the less likely. So, the possibility of superspreaders (or k), has a negative relationship with q and a positive relationship with p. In other words, as k increases q decreases, and as k increases p increases.
